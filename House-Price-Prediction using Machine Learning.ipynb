# %%
import pandas as pd

# %%
df_train= pd.read_csv('newtrain.csv')
df_test= pd.read_csv('newtest.csv')

# %%
#df_train.corr()['SalePrice'][:50]
# Out:
# Unnamed: 0         -0.021917
# LotFrontage         0.334771
# LotArea             0.263843
# OverallQual         0.790982
# YearBuilt           0.522897
# YearRemodAdd        0.507101
# MasVnrArea          0.472614
# BsmtFinSF1          0.386420
# BsmtUnfSF           0.214479
# TotalBsmtSF         0.613581
# 1stFlrSF            0.605852
# 2ndFlrSF            0.319334
# GrLivArea           0.708624
# BsmtFullBath        0.227122
# FullBath            0.560664
# HalfBath            0.284108
# BedroomAbvGr        0.168213
# KitchenAbvGr       -0.135907
# TotRmsAbvGrd        0.533723
# Fireplaces          0.466929
# GarageYrBlt         0.466754
# GarageCars          0.640409
# GarageArea          0.623431
# WoodDeckSF          0.324413
# OpenPorchSF         0.315856
# EnclosedPorch      -0.128578
# ScreenPorch         0.111447
# PoolArea            0.092404
# MoSold              0.046432
# SalePrice           1.000000
# MSZone_C (all)     -0.111257
# MSZone_FV           0.089950
# ...

# %%
#df_test.columns[:60]
# Out:
# Index(['Unnamed: 0', 'LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', 'ScreenPorch', 'PoolArea', 'MoSold',
#        'MSZone_C (all)', 'MSZone_FV', 'MSZone_RH', 'MSZone_RL', 'MSZone_RM',
#        'Street_Grvl', 'Street_Pave', 'Alley_Grvl', 'Alley_NA', 'Alley_Pave',
#        'LotShape_IR1', 'LotShape_IR2', 'LotShape_IR3', 'LotShape_Reg',
#        'LandContour_Bnk', 'LandContour_HLS', 'LandContour_Low',
#        'LandContour_Lvl', 'Utilities_AllPub', 'LotConfig_Corner',
#        'LotConfig_CulDSac', 'LotConfig_FR2', 'LotConfig_FR3',
#        'LotConfig_Inside', 'LandSlope_Gtl', 'LandSlope_Mod', 'LandSlope_Sev',
# ...

# %%
df_train.drop(['KitchenAbvGr','EnclosedPorch','PoolArea', 'MoSold', 'MSZone_C (all)', 'MSZone_FV','MSZone_RH', 'Street_Grvl',
              'Street_Pave', 'Alley_Grvl', 'Alley_Pave','LotShape_IR3','LandContour_Bnk','LandContour_Low','LandContour_Lvl',
              'Utilities_AllPub','LotConfig_Corner'], axis=1, inplace=True)
df_test.drop(['KitchenAbvGr','EnclosedPorch','PoolArea', 'MoSold', 'MSZone_C (all)', 'MSZone_FV','MSZone_RH', 'Street_Grvl',
              'Street_Pave', 'Alley_Grvl', 'Alley_Pave','LotShape_IR3','LandContour_Bnk','LandContour_Low','LandContour_Lvl',
              'Utilities_AllPub','LotConfig_Corner'], axis=1, inplace=True)

# %%
#df_train.corr()['SalePrice'][20:55]
# Out:
# GarageCars              0.640409
# GarageArea              0.623431
# WoodDeckSF              0.324413
# OpenPorchSF             0.315856
# ScreenPorch             0.111447
# SalePrice               1.000000
# MSZone_RL               0.245063
# MSZone_RM              -0.288065
# Alley_NA                0.123611
# LotShape_IR1            0.223284
# LotShape_IR2            0.126096
# LotShape_Reg           -0.267672
# LandContour_HLS         0.120014
# LotConfig_CulDSac       0.141818
# LotConfig_FR2          -0.006859
# LotConfig_FR3           0.018186
# LotConfig_Inside       -0.080538
# LandSlope_Gtl          -0.051116
# LandSlope_Mod           0.042981
# LandSlope_Sev           0.027998
# Neighborhood_Blmngtn    0.019066
# Neighborhood_Blueste   -0.020250
# Neighborhood_BrDale    -0.101303
# Neighborhood_BrkSide   -0.143648
# Neighborhood_ClearCr    0.055718
# Neighborhood_CollgCr    0.072626
# Neighborhood_Crawfor    0.071160
# Neighborhood_Edwards   -0.179949
# ...

# %%
df_train.drop(['LotConfig_FR2','LotConfig_FR3','LotConfig_Inside','LandSlope_Gtl','LandSlope_Mod','LandSlope_Sev',
             'Neighborhood_Blmngtn','Neighborhood_Blueste','Neighborhood_BrDale','Neighborhood_BrkSide','Neighborhood_ClearCr',
             'Neighborhood_CollgCr','Neighborhood_Crawfor','Neighborhood_Gilbert'], axis=1, inplace=True)
df_test.drop(['LotConfig_FR2','LotConfig_FR3','LotConfig_Inside','LandSlope_Gtl','LandSlope_Mod','LandSlope_Sev',
             'Neighborhood_Blmngtn','Neighborhood_Blueste','Neighborhood_BrDale','Neighborhood_BrkSide','Neighborhood_ClearCr',
             'Neighborhood_CollgCr','Neighborhood_Crawfor','Neighborhood_Gilbert'], axis=1, inplace=True)

# %%
df_train.drop(['Neighborhood_MeadowV','Neighborhood_Mitchel','Neighborhood_NAmes','Neighborhood_NPkVill','Neighborhood_NWAmes',
              'Neighborhood_OldTown','Neighborhood_SWISU','Neighborhood_Sawyer','Neighborhood_SawyerW','Neighborhood_Somerst',
              'Neighborhood_Timber','Neighborhood_Veenker','Condition1_Artery','Condition1_Feedr'], axis=1, inplace=True)
df_test.drop(['Neighborhood_MeadowV','Neighborhood_Mitchel','Neighborhood_NAmes','Neighborhood_NPkVill','Neighborhood_NWAmes',
              'Neighborhood_OldTown','Neighborhood_SWISU','Neighborhood_Sawyer','Neighborhood_SawyerW','Neighborhood_Somerst',
              'Neighborhood_Timber','Neighborhood_Veenker','Condition1_Artery','Condition1_Feedr'], axis=1, inplace=True)

# %%
#df_train.corr()['SalePrice'][40:75]
# Out:
# BldgType_1Fam          0.137483
# HouseStyle_1.5Fin     -0.163466
# HouseStyle_2Story      0.242880
# RoofStyle_Gable       -0.224744
# RoofStyle_Hip          0.235897
# RoofMatl_WdShngl       0.169324
# Exterior1st_CemntBd    0.133492
# Exterior1st_MetalSd   -0.167068
# Exterior1st_VinylSd    0.305009
# Exterior1st_Wd Sdng   -0.158619
# Exterior2nd_CmentBd    0.128183
# Exterior2nd_MetalSd   -0.162389
# Exterior2nd_Stone     -0.016754
# Exterior2nd_Stucco    -0.042416
# Exterior2nd_VinylSd    0.306389
# Exterior2nd_Wd Sdng   -0.161800
# Exterior2nd_Wd Shng   -0.040329
# MasVnrType_BrkCmn     -0.044394
# MasVnrType_BrkFace     0.198191
# MasVnrType_None       -0.367456
# MasVnrType_Stone       0.330476
# Foundation_BrkTil     -0.204117
# Foundation_CBlock     -0.343263
# Foundation_PConc       0.497734
# Foundation_Slab       -0.119740
# Foundation_Stone      -0.012103
# Foundation_Wood        0.002711
# Heating_GasA           0.092529
# Heating_GasW          -0.020103
# ...

# %%
df_train.drop(['Condition1_PosA','Condition1_PosN','Condition1_RRAe','Condition1_RRAn','Condition1_RRNe','Condition1_RRNn',
              'Condition2_Artery','Condition2_Feedr','Condition2_Norm','Condition2_PosA','Condition2_PosN','BldgType_2fmCon',
              'BldgType_Duplex','BldgType_Twnhs','BldgType_TwnhsE','HouseStyle_1.5Unf','HouseStyle_1Story','HouseStyle_2.5Unf',
              'HouseStyle_SFoyer','HouseStyle_SLvl','RoofStyle_Flat'], axis=1, inplace=True)
df_test.drop(['Condition1_PosA','Condition1_PosN','Condition1_RRAe','Condition1_RRAn','Condition1_RRNe','Condition1_RRNn',
              'Condition2_Artery','Condition2_Feedr','Condition2_Norm','Condition2_PosA','Condition2_PosN','BldgType_2fmCon',
              'BldgType_Duplex','BldgType_Twnhs','BldgType_TwnhsE','HouseStyle_1.5Unf','HouseStyle_1Story','HouseStyle_2.5Unf',
              'HouseStyle_SFoyer','HouseStyle_SLvl','RoofStyle_Flat'], axis=1, inplace=True)

# %%
df_train.drop(['RoofStyle_Gambrel','RoofStyle_Mansard','RoofStyle_Shed','RoofMatl_CompShg','RoofMatl_Tar&Grv','RoofMatl_WdShake',
              'Exterior1st_AsbShng','Exterior1st_AsphShn','Exterior1st_BrkComm','Exterior1st_BrkFace','Exterior1st_CBlock',
              'Exterior1st_HdBoard','Exterior1st_Plywood','Exterior1st_Stucco','Exterior1st_WdShing','Exterior2nd_AsbShng',
              'Exterior2nd_AsphShn','Exterior2nd_Brk Cmn','Exterior2nd_BrkFace','Exterior2nd_CBlock','Exterior2nd_HdBoard',
              'Exterior2nd_ImStucc','Exterior2nd_Plywood'], axis=1, inplace=True)
df_test.drop(['RoofStyle_Gambrel','RoofStyle_Mansard','RoofStyle_Shed','RoofMatl_CompShg','RoofMatl_Tar&Grv','RoofMatl_WdShake',
              'Exterior1st_AsbShng','Exterior1st_AsphShn','Exterior1st_BrkComm','Exterior1st_BrkFace','Exterior1st_CBlock',
              'Exterior1st_HdBoard','Exterior1st_Plywood','Exterior1st_Stucco','Exterior1st_WdShing','Exterior2nd_AsbShng',
              'Exterior2nd_AsphShn','Exterior2nd_Brk Cmn','Exterior2nd_BrkFace','Exterior2nd_CBlock','Exterior2nd_HdBoard',
              'Exterior2nd_ImStucc','Exterior2nd_Plywood'], axis=1, inplace=True)

# %%
df_train.drop(['Exterior2nd_Stone','Exterior2nd_Stucco','Exterior2nd_Wd Shng','MasVnrType_BrkCmn','Foundation_Slab',
              'Foundation_Stone','Foundation_Wood','Heating_GasA','Heating_GasW','Heating_Grav','Heating_Wall'], 
              axis=1, inplace=True)
df_test.drop(['Exterior2nd_Stone','Exterior2nd_Stucco','Exterior2nd_Wd Shng','MasVnrType_BrkCmn','Foundation_Slab',
              'Foundation_Stone','Foundation_Wood','Heating_GasA','Heating_GasW','Heating_Grav','Heating_Wall'], 
              axis=1, inplace=True)

# %%
#df_train.corr()['SalePrice'][60:]
# Out:
# CentralAir_N            -0.251328
# CentralAir_Y             0.251328
# Electrical_FuseA        -0.193978
# Electrical_FuseF        -0.126601
# Electrical_SBrkr         0.242357
# Functional_Typ           0.116462
# GarageType_Attchd        0.335961
# GarageType_BuiltIn       0.235449
# GarageType_Detchd       -0.354141
# GarageType_NA           -0.236832
# GarageFinish_Fin         0.419678
# GarageFinish_NA         -0.236832
# GarageFinish_RFn         0.169792
# GarageFinish_Unf        -0.410608
# PavedDrive_N            -0.212630
# PavedDrive_Y             0.231968
# Fence_MnPrv             -0.140613
# Fence_NA                 0.172184
# SaleType_New             0.357509
# SaleType_WD             -0.242598
# SaleCondition_Abnorml   -0.118069
# SaleCondition_Normal    -0.153990
# SaleCondition_Partial    0.352060
# Enc_ExterQual            0.682639
# Enc_BsmtQual             0.585207
# Enc_BsmtCond             0.212607
# Enc_BsmtExposure         0.374696
# ...

# %%
df_train.drop(['Electrical_FuseP','Functional_Maj1','Functional_Maj2','Functional_Min1','Functional_Min2',
              'Functional_Mod','Functional_Sev','GarageType_2Types','GarageType_Basment','GarageType_CarPort','PavedDrive_P',
              'Fence_GdPrv','Fence_GdWo','Fence_MnWw','MiscFeature_Gar2','MiscFeature_NA','MiscFeature_Othr','MiscFeature_Shed',
              'SaleType_COD','SaleType_CWD','SaleType_Con','SaleType_ConLD','SaleType_ConLI','SaleType_ConLw',
              'SaleType_Oth','SaleCondition_AdjLand','SaleCondition_Alloca','SaleCondition_Family','Enc_ExterCond'], 
              axis=1, inplace=True)
df_test.drop(['Electrical_FuseP','Functional_Maj1','Functional_Maj2','Functional_Min1','Functional_Min2',
              'Functional_Mod','Functional_Sev','GarageType_2Types','GarageType_Basment','GarageType_CarPort','PavedDrive_P',
              'Fence_GdPrv','Fence_GdWo','Fence_MnWw','MiscFeature_Gar2','MiscFeature_NA','MiscFeature_Othr','MiscFeature_Shed',
              'SaleType_COD','SaleType_CWD','SaleType_Con','SaleType_ConLD','SaleType_ConLI','SaleType_ConLw',
              'SaleType_Oth','SaleCondition_AdjLand','SaleCondition_Alloca','SaleCondition_Family','Enc_ExterCond'], 
              axis=1, inplace=True)

# %%
df_train.drop('Enc_BsmtFinType2', axis=1, inplace=True)
df_test.drop('Enc_BsmtFinType2', axis=1, inplace=True)

# %%
df_train.columns
# Out:
# Index(['Unnamed: 0', 'LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'ScreenPorch',
#        'SalePrice', 'MSZone_RL', 'MSZone_RM', 'Alley_NA', 'LotShape_IR1',
#        'LotShape_IR2', 'LotShape_Reg', 'LandContour_HLS', 'LotConfig_CulDSac',
#        'Neighborhood_Edwards', 'Neighborhood_IDOTRR', 'Neighborhood_NoRidge',
#        'Neighborhood_NridgHt', 'Neighborhood_StoneBr', 'Condition1_Norm',
#        'BldgType_1Fam', 'HouseStyle_1.5Fin', 'HouseStyle_2Story',
#        'RoofStyle_Gable', 'RoofStyle_Hip', 'RoofMatl_WdShngl',
#        'Exterior1st_CemntBd', 'Exterior1st_MetalSd', 'Exterior1st_VinylSd',
#        'Exterior1st_Wd Sdng', 'Exterior2nd_CmentBd', 'Exterior2nd_MetalSd',
# ...

# %%
df_train.drop('Unnamed: 0', axis=1, inplace=True)
df_test.drop('Unnamed: 0', axis=1, inplace=True)

# %%
len(df_train.columns), len(df_test.columns)
# Out:
# (93, 92)

# %%
final_df_train= df_train
final_df_train.to_csv('dropedtrain.csv', index=False)
final_df_test= df_test
final_df_test.to_csv('dropedtest.csv', index=False)

# %%
X= final_df_train.drop('SalePrice', axis=1)
y= final_df_train['SalePrice']
x_test= final_df_test

# %%
#from sklearn.model_selection import train_test_split

# %%
#X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2, random_state=12)

# %%
from xgboost import XGBRegressor

# %%
model_xg= XGBRegressor(random_state=23)

# %%
#model_xg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=23,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#model_xg.score(X_test, y_test), model_xg.score(X_train, y_train)
# Out:
# (0.8018493268539524, 0.9998019803820785)

# %%
params={'min_child_weight': [1,5, 10],
       'gamma': [0, 0.5,1],
       'subsample':[0.6,0.8,1.0],
       'colsample_bytree':[0.6,0.8,1.0],
       'max_depth': [3,4,5],
       'n_estimators':[500,1000,1500]}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
model_xg= RandomizedSearchCV(XGBRegressor(), param_distributions=params, cv=5)
#model_xg.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=100, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           random_state=None, reg_alpha=None,
# ...

# %%
model_xg.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.6, gamma=0.5, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=5,
#              min_child_weight=5, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1.0,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
model_xg= XGBRegressor(random_state=34, base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1.0, gamma=0.5, gpu_id=-1,
             importance_type='gain', interaction_constraints='',
             learning_rate=0.300000012, max_delta_step=0, max_depth=3,
             min_child_weight=3, monotone_constraints='()',
             n_estimators=2500, n_jobs=4, num_parallel_tree=1,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1.0,
             tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#model_xg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-db0b5e6a649a> in <module>
# ----> 1 model_xg.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
#model_xg.score(X_test, y_test), model_xg.score(X_train, y_train)
# Out:
# (0.8342152487283894, 0.9999961786499139)

# %%
model_xg.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1.0, gamma=0.5, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=3,
#              min_child_weight=3, missing=nan, monotone_constraints='()',
#              n_estimators=2500, n_jobs=4, num_parallel_tree=1, random_state=34,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1.0,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pre= model_xg.predict(x_test)

# %%
df_test=pd.read_csv('test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_submit=pd.DataFrame({'Id':df_test['Id'], 'SalePrice': y_pre})
df_submit.to_csv('submission2.csv', index=False)

# %%
Parameter_Trials={'n_estimators':[500,1000],
                  'criterion':['gini','entropy'],
                  'max_depth': [2,3,5],
                 'C': [0.001, 0.01 ], 
                'gamma': [0.001, 0.01]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
Grid_Search = GridSearchCV(model_xg, Parameter_Trials, cv=5, n_jobs=1, verbose=5)
GridSearchResults=Grid_Search.fit(X,y)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] C=0.001, criterion=gini, gamma=0.001, max_depth=2, n_estimators=500
# [14:05:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { C, criterion } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=0.001, criterion=gini, gamma=0.001, max_depth=2, n_estimators=500, score=0.909, total=   0.7s
# [CV] C=0.001, criterion=gini, gamma=0.001, max_depth=2, n_estimators=500
# [14:05:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { C, criterion } might not be used.
#
# ...

# %%
print(GridSearchResults.best_params_)
# Out:
# {'C': 0.001, 'criterion': 'gini', 'gamma': 0.001, 'max_depth': 2, 'n_estimators': 500}

# %%
model_xg1=XGBRegressor(C= 0.001, criterion= 'gini', gamma= 0.001, max_depth= 2, n_estimators= 500, random_state=34 )

# %%
model_xg1.fit(X,y)
# Out:
# [14:17:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { C, criterion } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(C=0.001, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, criterion='gini',
#              gamma=0.001, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=2, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=500, n_jobs=4,
#              num_parallel_tree=1, random_state=34, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='exact',
# ...

# %%
y_pre= model_xg1.predict(x_test)

# %%
df_test=pd.read_csv('test.csv')
df_submit=pd.DataFrame({'Id':df_test['Id'], 'SalePrice': y_pre})
df_submit.to_csv('submission4.csv', index=False)

# %%
df_tr= pd.read_csv('newtrain.csv')
df_te= pd.read_csv('newtest.csv')

# %%
df_tr.shape, df_te.shape
# Out:
# ((1460, 224), (1459, 223))

# %%
df1=pd.read_csv('dropedtrain.csv')
df1.shape
# Out:
# (1460, 93)

# %%
df2= pd.read_csv('dropedtest.csv')
df2.shape
# Out:
# (1459, 92)

# %%
#submission scored 0.13889
#rank is 3987
